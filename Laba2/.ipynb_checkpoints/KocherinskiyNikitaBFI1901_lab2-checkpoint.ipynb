# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# ### Цель

# %% [markdown]
# Реализовать классификацию между камнями (R) и металлическими цилиндрами (M) на основе данных об отражении сигналов радара от поверхностей. 60 входных значений показывают силу отражаемого сигнала под определенным углом.Входные данные нормализованы и находятся в промежутке от 0 до 1.

# %% [markdown]
# ### Задачи

# %% [markdown]
# 1. Ознакомиться с задачей бинарной классификации
# 2. Загрузить данные
# 3. Создать модель ИНС в tf.Keras
# 4. Настроить параметры обучения
# 5. Обучить и оценить модель
# 6. Изменить модель и провести сравнение. Объяснить результаты

# %% [markdown]
# ## Выполнение работы

# %%
import pandas
import matplotlib.pyplot as plt 
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Набор данных загружается напрямую с помощью pandas. Затем необходимо разделить
# атрибуты (столбцы) на 60 входных параметров (X) и 1 выходной (Y).

# %%
dataframe = pandas.read_csv("sonar.csv", header=None)
dataset = dataframe.values
X = dataset[:,0:60].astype(float)
Y = dataset[:,60]

# %% [markdown]
# Выходные параметры представлены строками (“R” и “M”), которые необходимо перевести
# в целочисленные значения 0 и 1 соответственно. Для этого применяется LabelEncoder из
# scikit-learn.

# %%
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)

# %% [markdown]
# Теперь можно задать базовую архитектуру сети.

# %%
model = Sequential()
model.add(Dense(60, input_dim = 60, kernel_initializer='normal', activation='relu'))
model.add(Dense(1,  kernel_initializer='normal', activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Теперь можно начинать обучение сети, для чего в случае использования библиотеки Keras
# достаточно вызвать метод fit сети — он пытается адаптировать (fit) модель под обучающие
# данные.

# %%
f = model.fit(X, encoded_Y, epochs=100, batch_size=10, validation_split=0.1)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 1s 10ms/step - loss: 0.6945 - accuracy: 0.4866 - val_loss: 0.6823 - val_accuracy: 1.0000
# Epoch 2/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6875 - accuracy: 0.5615 - val_loss: 0.6699 - val_accuracy: 1.0000
# Epoch 3/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6848 - accuracy: 0.6417 - val_loss: 0.6967 - val_accuracy: 0.3333
# Epoch 4/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6750 - accuracy: 0.6738 - val_loss: 0.6644 - val_accuracy: 0.9048
# Epoch 5/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6641 - accuracy: 0.7166 - val_loss: 0.6928 - val_accuracy: 0.3810
# Epoch 6/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6495 - accuracy: 0.6898 - val_loss: 0.6985 - val_accuracy: 0.3810
# Epoch 7/100
# ...

# %%
plt.plot(f.history['accuracy'], color=('green'))
plt.plot(f.history['val_accuracy'], color=('red'))
plt.title('График точности',fontsize=12)
plt.ylabel('Точность',fontsize=12)
plt.xlabel('Количество эпох',fontsize=12)
plt.legend(['Обучение','Тестирование'],fontsize=12)

# %%
plt.plot(f.history['loss'], color=('green'))
plt.plot(f.history['val_loss'], color=('red'))
plt.title('График потерь',fontsize=12)
plt.ylabel('Потери',fontsize=12)
plt.xlabel('Количество эпох',fontsize=12)
plt.legend(['Обучение','Тестирование'],fontsize=12)

# %% [markdown]
# ## Требования
# 1. Изучить влияние кол-ва нейронов на слое на результат обучения модели.
# 2. Изучить влияние кол-ва слоев на результат обучения модели
# 3. Построить графики ошибки и точности в ходе обучения
# 4. Провести сравнение полученных сетей, объяснить результат

# %% [markdown]
# ## Выполнение работы
#
# #### Уменьшить размер входного слоя в два раза

# %%
import pandas
import matplotlib.pyplot as plt 
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

dataframe = pandas.read_csv("sonar.csv", header=None)
dataset = dataframe.values
X = dataset[:,0:60].astype(float)
Y = dataset[:,60]

encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)

model = Sequential()
model.add(Dense(30, input_dim = 60, kernel_initializer='normal', activation='relu'))
model.add(Dense(1,  kernel_initializer='normal', activation='sigmoid'))

model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])

f = model.fit(X, encoded_Y, epochs=100, batch_size=10, validation_split=0.1)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 1s 15ms/step - loss: 0.6913 - accuracy: 0.6150 - val_loss: 0.6974 - val_accuracy: 0.3333
# Epoch 2/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.6866 - accuracy: 0.7112 - val_loss: 0.6912 - val_accuracy: 0.4286
# Epoch 3/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6828 - accuracy: 0.6738 - val_loss: 0.7152 - val_accuracy: 0.1429
# Epoch 4/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6740 - accuracy: 0.7540 - val_loss: 0.6856 - val_accuracy: 0.5238
# Epoch 5/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6665 - accuracy: 0.7326 - val_loss: 0.6873 - val_accuracy: 0.4286
# Epoch 6/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6564 - accuracy: 0.7487 - val_loss: 0.7123 - val_accuracy: 0.3810
# Epoch 7/100
# ...

# %%
plt.plot(f.history['accuracy'], color=('green'))
plt.plot(f.history['val_accuracy'], color=('red'))
plt.title('График точности',fontsize=12)
plt.ylabel('Точность',fontsize=12)
plt.xlabel('Количество эпох',fontsize=12)
plt.legend(['Обучение','Тестирование'],fontsize=12)

# %%
plt.plot(f.history['loss'], color=('green'))
plt.plot(f.history['val_loss'], color=('red'))
plt.title('График потерь',fontsize=12)
plt.ylabel('Потери',fontsize=12)
plt.xlabel('Количество эпох',fontsize=12)
plt.legend(['Обучение','Тестирование'],fontsize=12)

# %% [markdown]
# #### Добавить промежуточный (скрытый) слой

# %%
import pandas
import matplotlib.pyplot as plt 
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

dataframe = pandas.read_csv("sonar.csv", header=None)
dataset = dataframe.values
X = dataset[:,0:60].astype(float)
Y = dataset[:,60]

encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)

model = Sequential()
model.add(Dense(30, input_dim = 60, kernel_initializer='normal', activation='relu'))
model.add(Dense(15, kernel_initializer='normal', activation='tanh'))
model.add(Dense(1,  kernel_initializer='normal', activation='sigmoid'))

model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])

f = model.fit(X, encoded_Y, epochs=100, batch_size=10, validation_split=0.1)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 1s 9ms/step - loss: 0.6931 - accuracy: 0.4973 - val_loss: 0.6958 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6917 - accuracy: 0.6898 - val_loss: 0.6930 - val_accuracy: 0.3333
# Epoch 3/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6892 - accuracy: 0.6631 - val_loss: 0.6858 - val_accuracy: 0.9048
# Epoch 4/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6821 - accuracy: 0.6791 - val_loss: 0.6914 - val_accuracy: 0.3810
# Epoch 5/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6693 - accuracy: 0.6952 - val_loss: 0.6878 - val_accuracy: 0.3810
# Epoch 6/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6434 - accuracy: 0.7219 - val_loss: 0.7090 - val_accuracy: 0.3810
# Epoch 7/100
# ...

# %%
plt.plot(f.history['accuracy'], color=('green'))
plt.plot(f.history['val_accuracy'], color=('red'))
plt.title('График точности',fontsize=12)
plt.ylabel('Точность',fontsize=12)
plt.xlabel('Количество эпох',fontsize=12)
plt.legend(['Обучение','Тестирование'],fontsize=12)

# %%
plt.plot(f.history['loss'], color=('green'))
plt.plot(f.history['val_loss'], color=('red'))
plt.title('График потерь',fontsize=12)
plt.ylabel('Потери',fontsize=12)
plt.xlabel('Количество эпох',fontsize=12)
plt.legend(['Обучение','Тестирование'],fontsize=12)

# %% [markdown]
# #### Создание собственной модели

# %%
import pandas
import matplotlib.pyplot as plt 
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

dataframe = pandas.read_csv("sonar.csv", header=None)
dataset = dataframe.values
X = dataset[:,0:60].astype(float)
Y = dataset[:,60]

encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)

model = Sequential()
model.add(Dense(60, input_dim = 60, kernel_initializer='normal', activation='relu'))
model.add(Dense(45, kernel_initializer='normal', activation='tanh'))
model.add(Dense(30, kernel_initializer='normal', activation='tanh'))
model.add(Dense(15, kernel_initializer='normal', activation='tanh'))
model.add(Dense(1,  kernel_initializer='normal', activation='sigmoid'))

model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])

f = model.fit(X, encoded_Y, epochs=100, batch_size=10, validation_split=0.1)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 1s 9ms/step - loss: 0.6931 - accuracy: 0.5187 - val_loss: 0.6958 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6917 - accuracy: 0.6417 - val_loss: 0.6969 - val_accuracy: 0.0476
# Epoch 3/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.6790 - accuracy: 0.7059 - val_loss: 0.6733 - val_accuracy: 0.8095
# Epoch 4/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6337 - accuracy: 0.6738 - val_loss: 0.5502 - val_accuracy: 0.9048
# Epoch 5/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5662 - accuracy: 0.7219 - val_loss: 0.7741 - val_accuracy: 0.3333
# Epoch 6/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5288 - accuracy: 0.7380 - val_loss: 0.8294 - val_accuracy: 0.3333
# Epoch 7/100
# ...

# %%
plt.plot(f.history['accuracy'], color=('green'))
plt.plot(f.history['val_accuracy'], color=('red'))
plt.title('График точности',fontsize=12)
plt.ylabel('Точность',fontsize=12)
plt.xlabel('Количество эпох',fontsize=12)
plt.legend(['Обучение','Тестирование'],fontsize=12)

# %%
plt.plot(f.history['loss'], color=('green'))
plt.plot(f.history['val_loss'], color=('red'))
plt.title('График потерь',fontsize=12)
plt.ylabel('Потери',fontsize=12)
plt.xlabel('Количество эпох',fontsize=12)
plt.legend(['Обучение','Тестирование'],fontsize=12)

# %% [markdown]
# ## Вывод

# %% [markdown]
# Первая модель: loss: 0.2899 - accuracy: 0.8984 - val_loss: 0.3611 - val_accuracy: 0.8095
#
# Вторая модель: loss: 0.3432 - accuracy: 0.8503 - val_loss: 0.5003 - val_accuracy: 0.6667
#
# Третья модель: loss: 0.2315 - accuracy: 0.8984 - val_loss: 0.3588 - val_accuracy: 0.8571
#
# Четвертая модель: loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1087 - val_accuracy: 0.9524
#
# Таким образом можно сделать вывод о том что 4 модель лучше предыдущих.
